# %%
class ListMath:
    def __init__(self, arg=[]):
        self.lst_math = [i for i in arg if type(i) in (int, float)]

    def do(self, fn_name, other, new=True):
        result = [getattr(i, fn_name)(other) for i in self.lst_math]
        if new:
            return ListMath(result)
        else:
            self.lst_math = result
            return self

    def __add__(self, other):
        return self.do('__add__', other)

    def __sub__(self, other):
        return self.do('__sub__', other)

    def __rsub__(self, other):
        return self.do('__rsub__', other)

    def __mul__(self, other):
        return self.do('__mul__', other)

    def __rmul__(self, other):
        return self.do('__rmul__', other)

    def __truediv__(self, other):
        return self.do('__truediv__', other)

    def __iadd__(self, other):
        return self.do('__add__', other, False)

    def __isub__(self, other):
        return self.do('__sub__', other, False)

    def __imul__(self, other):
        return self.do('__mul__', other, False)

    def __idiv__(self, other):
        return self.do('__truediv__', other, False)

# %%
class ListMath:
    def __init__(self, lst_math = []):
        self.lst_math = lst_math 
    
    @classmethod
    def chek_value(cls, value):
        return type(value) in (int, float)
    
    def __setattr__(self, key, value):
        if key == 'lst_math':
            value = list(filter(lambda x: type(x) in (int, float), value))
            object.__setattr__(self, key, value)
                
    def __add__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: x + other, self.lst_math[:])))
    
    def __radd__(self, other):
        return self.lst_math + other
    
    def __iadd__(self, other):
        if self.chek_value(other):
            self.lst_math = list(map(lambda x: x + other, self.lst_math[:]))
            return self
    
    def __sub__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: x - other, self.lst_math[:])))
    
    def __rsub__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: other - x, self.lst_math[:])))
    
    def __isub__(self, other):
        if not self.chek_value(other):
            raise TypeError('Неверный тип')
        self.lst_math = list(map(lambda x: x - other, self.lst_math[:]))
        return self
    
    def __mul__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: x * other, self.lst_math[:])))
    
    def __rmul__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: x * other, self.lst_math[:])))
    
    def __imul__(self, other):
        if not self.chek_value(other):
            raise TypeError('Неверный тип')
        self.lst_math = list(map(lambda x: x * other, self.lst_math[:]))
        return self
    
    def __truediv__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: x / other, self.lst_math[:])))
    
    def __rtruediv__(self, other):
        if self.chek_value(other):
            return ListMath(list(map(lambda x: other / x, self.lst_math[:])))
    
    def __itruediv__(self, other):
        if not self.chek_value(other):
            raise TypeError('Неверный тип')
        self.lst_math = list(map(lambda x: x / other, self.lst_math[:]))
        return self

# %%
lst = lst + 76 # сложение каждого числа списка с определенным числом
lst += 76.7  # сложение каждого числа списка с определенным числом
lst = lst - 76 # вычитание из каждого числа списка определенного числа
lst = 7.0 - lst # вычитание из числа каждого числа списка
lst -= 76.3
lst = lst * 5 # умножение каждого числа списка на указанное число (в данном случае на 5)
lst = 5 * lst # умножение каждого числа списка на указанное число (в данном случае на 5)
lst *= 5.54
lst = lst / 13 # деление каждого числа списка на указанное число (в данном случае на 13)
lst /= 13.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\73B5~1\AppData\Local\Temp/ipykernel_12156/3232178935.py in <module>
# ----> 1 lst = lst + 76 # сложение каждого числа списка с определенным числом
#       2 lst += 76.7  # сложение каждого числа списка с определенным числом
#       3 lst = lst - 76 # вычитание из каждого числа списка определенного числа
#       4 lst = 7.0 - lst # вычитание из числа каждого числа списка
#       5 lst -= 76.3
#
# NameError: name 'lst' is not defined
